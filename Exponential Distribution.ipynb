# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = range(100)
lst = []
for i in x:
    y = -0.1*i
    lst.append((2.71)**y)
sns.distplot(lst, hist=True)

# %%
def main():
    x = np.linspace(-1,1,100)
    y = np.exp(x)
    
    plt.figure()
    plt.plot(x, -np.exp(-x))
    plt.xlabel('$x$')
    plt.ylabel('$-\exp(-x*0.1)$')
    
    plt.show()
    

main()
